# %%
import pandas as pd
import os 

path = '../Data/Augment/Augment_KFashion_Image/'
augment_li = sorted(os.listdir(path), key=lambda x:int(os.path.splitext(x)[0]))
augment_li = pd.DataFrame(augment_li,columns=['Image'])
augment_li.to_csv('augment_file_list.csv',index=False)
augment_li
# Out:
#             Image
# 0         101.jpg
# 1         202.jpg
# 2         218.jpg
# 3         270.jpg
# 4         302.jpg
# ...           ...
# 1765  1344413.jpg
# 1766  1345749.jpg
# 1767  1345814.jpg
# 1768  1346531.jpg
# 1769  1347329.jpg
#
# [1770 rows x 1 columns]

# %%
import os
import pandas as pd
path = '../Data/Total/Total_Image/'
total_li = os.listdir(path)
len(total_li)
# Out:
# 2000
